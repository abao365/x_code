# %%
# -*- coding: utf-8 -*-
import pandas as pd
import sys
default_encoding = 'utf-8'
if sys.getdefaultencoding() != default_encoding:
    reload(sys)
    sys.setdefaultencoding(default_encoding)

# %%
rawDataDir_poi='/Users/leidelong/work/projects/knowledge_graph/granularity_poi_poigraph_info.csv'
rawDataDir_poigraph='/Users/leidelong/work/projects/knowledge_graph/granularity_poigraph.csv'

df_poi=pd.read_csv(rawDataDir_poi,sep='	')
df_poigraph=pd.read_csv(rawDataDir_poigraph,sep='	')

# %%
print df_poi.shape
print df_poigraph.shape
# Out:
# (21721, 14)
# (403, 9)

# %%
print "df_poi.columns:",df_poi.columns
print "df_poigraph.columns:",df_poigraph.columns
# Out:
# df_poi.columns: Index([u'bm_delivery_area_id', u'platform_poi_id', u'sender_lng',
#        u'sender_lat', u'ct', u'poi_id', u'poi_name', u'da_id', u'da_name',
#        u'city_id', u'city_name', u'org_detail_type', u'org_detail_type_name',
#        u'poi_class_id'],
#       dtype='object')
# df_poigraph.columns: Index([u'bm_delivery_area_id', u'poi_class_id', u'poi_class_center_lng',
#        u'poi_class_center_lat', u'da_name', u'city_id', u'city_name',
#        u'org_type', u'org_type_name'],
#       dtype='object')

# %%
df_area_id=df_poigraph['bm_delivery_area_id'].drop_duplicates()

# %%
df_area_id.shape
print df_poi.dtypes
# Out:
# bm_delivery_area_id       int64
# platform_poi_id           int64
# sender_lng                int64
# sender_lat                int64
# ct                        int64
# poi_id                    int64
# poi_name                 object
# da_id                     int64
# da_name                  object
# city_id                   int64
# city_name                object
# org_detail_type           int64
# org_detail_type_name     object
# poi_class_id            float64
# dtype: object

# %%
area_id_list=df_area_id.tolist()
print area_id_list
# Out:
# [1887, 2197, 2345, 2350, 2353, 2363, 2364, 2366, 2367, 2369, 2375, 2377, 2603, 2609, 2664, 2667, 2739, 2742, 2829, 4968, 2002330, 2002478, 2002539, 2002772, 2002773, 2002774, 2002775, 2002778, 2002783, 2002822, 2002832, 2002836, 2002840, 2002907, 2003036, 2003040, 2003194, 2003195, 2003196, 2003197, 2003198, 2003199, 2003200, 2003201, 2003203, 2003768, 2003833, 2003834, 2003843, 2003856, 2003858, 2003861, 2003863, 2003870, 2003875, 2003912, 2003913, 2004277, 2004332, 2004335, 2004336, 2004355, 2004443, 2004446, 2004491, 2004492, 2004507, 2004525, 2004526, 2004527, 2004530, 2004531, 2004533, 2004541, 2004549, 2004705, 2004716, 2004718, 2004722, 2004724, 2004727, 2004730, 2004732, 2004735, 2004736, 2004788, 2004789, 2004798, 2004799, 2004801, 2004802, 2004806, 2004808, 2004920, 2004926, 2004929, 2004932, 2005206, 2005349, 2005489, 2005491, 2005591, 2005608, 2005609, 2005627, 2005631, 2005633, 2005680, 2005701, 2005724, 2005728, 2005732, 2005739, 2005744, 2005749, 2005774, 2005775, 2005791, 2005796, 2005820, 2005932, 2006595, 2006596, 2006598, 2006605, 2006615, 2006616, 2006629, 2006631, 2006632, 2006633, 2006635, 2006640, 2006667, 2006668, 2006669, 2006670, 2006672, 2006684, 2006686, 2006694, 2006785, 2006787, 2006788, 2007026, 2007029, 2007030, 2007031, 2007033, 2007035, 2007036, 2008200, 2008201, 2008202, 2008371, 2008374, 2008376, 2008380, 2008382, 2008419, 2008502, 2008535, 2008557, 2008664, 2008665, 2008699, 2008701, 2008702]

# %%
count=0

id_color={'0':'blue','1':'green','2':'purple','3':'yellow','4':'pink','5':'brown','6':'white','7':'maroon','-1':'gray'}

for id in area_id_list:
    print count
    count=count+1
    if count==3:
        break
    
    tmp_df_poi=df_poi[df_poi['bm_delivery_area_id']==id]
    tmp_df_area_id=df_poigraph[df_poigraph['bm_delivery_area_id']==id]
    
    import folium
    
#     tmp_titles="https://rt{s}.map.gtimg.com/realtimerender?z={z}&x={x}&y={y}&type=vector&style=0"
    map_1 = folium.Map(location=[31.102557, 121.609862],
                       zoom_start=12)
    
    #商圈可视化
    for calss_index in tmp_df_area_id.index :
        tmp_class_id=tmp_df_area_id.at[calss_index,"poi_class_id"]
        tmp_poi_class_center_lat =float(tmp_df_area_id.at[calss_index,"poi_class_center_lat"])/1000000
        tmp_poi_class_center_lng =float(tmp_df_area_id.at[calss_index,"poi_class_center_lng"])/1000000
        folium.Marker([tmp_poi_class_center_lat, tmp_poi_class_center_lng], popup=str(tmp_class_id),icon=folium.Icon(color='red',icon='info-sign')).add_to(map_1)
        
    
    #POI可视化
    for poi_index in tmp_df_poi.index :
        tmp_poi_class_id=tmp_df_poi.at[poi_index,"poi_class_id"]
        tmp_poi_name=tmp_df_poi.at[poi_index,"poi_name"]
        tmp_poi_lat =float(tmp_df_poi.at[poi_index,"sender_lat"])/1000000
        tmp_poi_lng =float(tmp_df_poi.at[poi_index,"sender_lng"])/1000000
        folium.Marker([tmp_poi_lat, tmp_poi_lng], popup='poi name :'+str(tmp_poi_name)  +',class id:'+str(tmp_poi_class_id),icon=folium.Icon(color=id_color.get(str(int(tmp_poi_class_id))),icon='info-sign')).add_to(map_1)
        
    path=str(id)+'_map.html'
    print path
    map_1.save(path)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
